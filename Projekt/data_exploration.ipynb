# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df["track_genre"].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...

# %%
df["Unnamed: 0"]
# Out:
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 113995    113995
# 113996    113996
# 113997    113997
# 113998    113998
# 113999    113999
# Name: Unnamed: 0, Length: 114000, dtype: int64

# %%
df.drop(["Unnamed: 0", "track_id", "track_genre","album_name", "track_name", "artists"], axis=1, inplace=True)
df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 0               73       230666     False         0.676  0.4610    1
# 1               55       149610     False         0.420  0.1660    1
# 2               57       210826     False         0.438  0.3590    0
# 3               71       201933     False         0.266  0.0596    0
# 4               82       198853     False         0.618  0.4430    2
# ...            ...          ...       ...           ...     ...  ...
# 113995          21       384999     False         0.172  0.2350    5
# 113996          22       385000     False         0.174  0.1170    0
# 113997          22       271466     False         0.629  0.3290    0
# 113998          41       283893     False         0.587  0.5060    7
# 113999          22       241826     False         0.526  0.4870    1
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   popularity        114000 non-null  int64
#  1   duration_ms       114000 non-null  int64
#  2   explicit          114000 non-null  bool
#  3   danceability      114000 non-null  float64
#  4   energy            114000 non-null  float64
#  5   key               114000 non-null  int64
#  6   loudness          114000 non-null  float64
#  7   mode              114000 non-null  int64
#  8   speechiness       114000 non-null  float64
#  9   acousticness      114000 non-null  float64
#  10  instrumentalness  114000 non-null  float64
#  11  liveness          114000 non-null  float64
#  12  valence           114000 non-null  float64
#  13  tempo             114000 non-null  float64
#  14  time_signature    114000 non-null  int64
# dtypes: bool(1), float64(9), int64(5)
# ...

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))


sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', annot_kws={'size': 10, 'color': 'white'}, fmt='.3f')
# Out:
# <Axes: >

# %%
popularity_bins = [0, 20, 40, 60, 80, 100]

df['popularity_labels'] = pd.cut(df['popularity'], bins=popularity_bins, labels=['Bardzo niska', 'Niska', 'Srednia', 'Wysoka', 'Bardzo wysoka'])
df['popularity_labels'] = np.where(df['popularity'] == 0, 'Bardzo niska', df['popularity_labels'])


df
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 0               73       230666     False         0.676  0.4610    1
# 1               55       149610     False         0.420  0.1660    1
# 2               57       210826     False         0.438  0.3590    0
# 3               71       201933     False         0.266  0.0596    0
# 4               82       198853     False         0.618  0.4430    2
# ...            ...          ...       ...           ...     ...  ...
# 113995          21       384999     False         0.172  0.2350    5
# 113996          22       385000     False         0.174  0.1170    0
# 113997          22       271466     False         0.629  0.3290    0
# 113998          41       283893     False         0.587  0.5060    7
# 113999          22       241826     False         0.526  0.4870    1
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
df["popularity_labels"].value_counts()
# Out:
# popularity_labels
# Bardzo niska     34177
# Niska            33149
# Srednia          33104
# Wysoka           12616
# Bardzo wysoka      954
# Name: count, dtype: int64

# %% [markdown]
# **to jest największy problem zbioru. Poniżej próbowałem zastosować oversampling, czyli sztucznie zwiększyć ilość przypadków gdzie była bardzo wysoka popularność ale to nic nie dało**

# %%
df[df["popularity"]==0]
# Out:
#         popularity  duration_ms  explicit  danceability  energy  key  \
# 23               0       216386     False         0.572   0.454    3
# 24               0       231266     False         0.796   0.667    5
# 26               0       131760     False         0.620   0.309    5
# 27               0       273653     False         0.633   0.429    4
# 28               0       131760     False         0.620   0.309    5
# ...            ...          ...       ...           ...     ...  ...
# 113046           0       117226     False         0.696   0.715    7
# 113047           0       175426     False         0.581   0.436    8
# 113048           0       193653     False         0.413   0.437    1
# 113049           0       217120     False         0.607   0.884    2
# 113099           0       160199     False         0.412   0.340    4
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
df_labeled = df.drop('popularity', axis=1)

# %%
df_labeled['popularity_labels_encoded'] = df_labeled['popularity_labels'].replace(
    { 'Bardzo niska': 0, 'Niska': 1, 'Srednia': 2, 'Wysoka': 3, 'Bardzo wysoka': 4}
)

df_labeled
# Out:
# /tmp/ipykernel_28472/941980312.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_labeled['popularity_labels_encoded'] = df_labeled['popularity_labels'].replace(
#         duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 0            230666     False         0.676  0.4610    1    -6.746     0
# 1            149610     False         0.420  0.1660    1   -17.235     1
# 2            210826     False         0.438  0.3590    0    -9.734     1
# 3            201933     False         0.266  0.0596    0   -18.515     1
# 4            198853     False         0.618  0.4430    2    -9.681     1
# ...             ...       ...           ...     ...  ...       ...   ...
# ...

# %%
df_labeled["popularity_labels_encoded"].unique()
# Out:
# array([3, 2, 4, 0, 1])

# %%
df_labeled['popularity_labels'].unique()
# Out:
# array(['Wysoka', 'Srednia', 'Bardzo wysoka', 'Bardzo niska', 'Niska'],
#       dtype=object)

# %%
df_labeled.drop('popularity_labels', axis=1, inplace=True)

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter

# Podziel dane na testowe i treningowe
X_train, X_test, y_train, y_test = train_test_split(df_labeled.drop('popularity_labels_encoded', axis=1), df_labeled['popularity_labels_encoded'], test_size=0.2, random_state=42)

# smote = SMOTE(random_state=42)
# X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# print(f"Przed oversamplingiem: {Counter(y_train)}")
# print(f"Po oversamplingu: {Counter(y_train_resampled)}")

# %% [markdown]
# To zakomentowane to próba oversamplingu ale to tylko pogorszyło wyniki sieci

# %%
# X_train = X_train_resampled
# y_train = y_train_resampled

# %%
X_test.columns
# Out:
# Index(['duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
X_test.values.shape
# Out:
# (22800, 14)

# %%
X_test.values[0]
# Out:
# array([440247, False, 0.369, 0.598, 7, -6.984, 1, 0.0304, 0.00511, 0.0,
#        0.176, 0.0466, 148.014, 4], dtype=object)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import History
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam


X_train = X_train.values
y_train = y_train.values
X_test = X_test.values
y_test = y_test.values

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential()
model.add(Dense(32, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(5, activation='softmax'))

history = History()

model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

#early_stop = EarlyStopping(monitor='val_loss', patience=8)
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test),callbacks=[history])

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
train_loss, train_acc = model.evaluate(X_train, y_train)
test_loss, test_acc = model.evaluate(X_test, y_test)

print('Strata na danych treningowych:', train_loss)
print('Dokładność na danych treningowych:', train_acc)
print('Strata na danych testowych:', test_loss)
print('Dokładność na danych testowych:', test_acc)

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Values')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# /home/mati/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2850/2850 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.3566 - loss: 1.3594 - val_accuracy: 0.4078 - val_loss: 1.2841
# Epoch 2/20
# 2850/2850 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.4071 - loss: 1.2809 - val_accuracy: 0.4215 - val_loss: 1.2689
# Epoch 3/20
# 2850/2850 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.4146 - loss: 1.2727 - val_accuracy: 0.4273 - val_loss: 1.2635
# Epoch 4/20
# 2850/2850 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.4256 - loss: 1.2636 - val_accuracy: 0.4295 - val_loss: 1.2581
# Epoch 5/20
# ...

# %%
from sklearn.metrics import confusion_matrix

cm_model = confusion_matrix(y_test, y_pred_classes)
print('\nMacierz pomyłek dla sieci neuronowej:')
print(cm_model)
sns.heatmap(cm_model, annot=True, fmt='d', cmap='YlGnBu')

# Add labels and title
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Decision Tree Confusion Matrix')
# Out:
# Macierz pomyłek dla sieci neuronowej:
# [[3627 1476 1747   29    0]
#  [1606 2731 2304   13    0]
#  [1458 1460 3658   34    0]
#  [ 765  583 1111   29    0]
#  [  85   23   59    2    0]]
# Text(0.5, 1.0, 'Decision Tree Confusion Matrix')

# %% [markdown]
# zgodnie z tym
# ```
# Bardzo niska(0)     34177
# Niska(1)            33149
# Srednia(2)          33104
# Wysoka(3)           12616
# Bardzo wysoka(4)      954
# ```
# widać, że model nauczył się zgdywać głownie 3 pierwsze klasy
# Tych najbardziej popularnych było na tyle mało że nawet nie dostały się do zbioru testowego :///

# %% [markdown]
# model ma trochę ponad 40% skuteczności co brzmi bardzo słabo ale sieć klasyfikowała w ramach 5 grup więc jakby losowo zgadywała to statystycznie miałąby 20% skuteczności, więc i tak udało się dwa razy lepszą sieć zrobić. Pewnie by dało się jakoś ulepszyć jeszcze wyniki ale zajęło by to trochę za dużo czasu

# %%
import pickle

# Save the model
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %% [markdown]
# ***=====================================================***

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

model_lr = LogisticRegression(multi_class='multinomial')

model_lr.fit(X_train, y_train)

y_pred_lr = model_lr.predict(X_test)
y_pred_lr_classes = np.argmax(y_pred_lr)
accuracy = accuracy_score(y_test, y_pred_lr)
print("Dokładność modelu:", accuracy)
# Out:
# Dokładność modelu: 0.3763157894736842

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix


accuracy = accuracy_score(y_test, y_pred_lr)
precision = precision_score(y_test, y_pred_lr, average='weighted')
recall = recall_score(y_test, y_pred_lr, average='weighted')
f1 = f1_score(y_test, y_pred_lr, average='weighted')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

from sklearn.metrics import confusion_matrix

lr_confusion_matrix = confusion_matrix(y_test, y_pred_lr)

sns.heatmap(lr_confusion_matrix, annot=True, fmt='d', cmap='YlGnBu')

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Decision Tree Confusion Matrix')

plt.show()
# Out:
# Accuracy: 0.3763157894736842
# Precision: 0.3725607189275467
# Recall: 0.3763157894736842
# F1 Score: 0.3533825103580099
# /home/mati/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **Tutaj próbowałem zobaczyć czy może regresja logistyczna da lepsze wyniki. Nie dała**
